# %% [markdown]
# data preprocessing

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from datetime import datetime

# %%
# read in data
df_orig = pd.read_csv('data/2019aug/dlistings.csv', low_memory=False)

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48864 entries, 0 to 48863
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(22), int64(21), object(63)
# memory usage: 39.5+ MB

# %%
# check for null values
n_nulls = defaultdict()
for col in df_orig.columns:
    n_nulls[col] = sum(pd.isnull(df_orig[col]).values)

# %%
# use this line to see all the columns
cols = df_orig.columns.tolist()

# %%
# remove unwanted columns
to_rm = ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'thumbnail_url','experiences_offered', 
        'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url','host_name',
        'host_location','host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
        'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 
         'availability_90', 'availability_365', 'calendar_last_scraped','requires_license', 'license', 
         'calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms', 
         'calculated_host_listings_count_shared_rooms']

# %%
df_eda = df_orig.drop(to_rm, axis=1)

# %%
df_eda.columns
# Out:
# Index(['summary', 'space', 'description', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'host_since',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'number_of_reviews',
#        'number_of_reviews_ltm', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
np.unique(df_orig['requires_license'], return_counts=True)
# Out:
# (array(['f', 't'], dtype=object), array([48863,     1]))

# %%
# test textblob functionality
from textblob import TextBlob

# %%
blob = TextBlob(df_eda['summary'][0])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.2826530612244898, subjectivity=0.5806122448979592)

# %%
df_eda['summary'].fillna(value='', axis=0, inplace=True)

# %%
# string cols
str_cols = ['summary', 'space', 'description', 'neighborhood_overview', 'notes', 
            'transit', 'access', 'interaction', 'house_rules']

# %%
# modify all str_cols to use textblob
for col in str_cols:
    df_eda[col].fillna(value='', axis=0, inplace=True)

# %%
df_eda['summary_p'] = df_eda['summary'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df_eda['summary_s'] = df_eda['summary'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
# get polarity and subjectivity from str_cols
for string in str_cols:
    df_eda[add_p(string)] = df_eda[string].apply(lambda x: TextBlob(x).sentiment.polarity)
    df_eda[add_s(string)] = df_eda[string].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
# help naming
def add_p(string):
    return string + '_p'

def add_s(string):
    return string + '_s'

# %%
df_eda['access_p']
# Out:
# 0        0.350000
# 1        0.000000
# 2        0.221875
# 3        0.000000
# 4        0.000000
#            ...
# 48859    0.000000
# 48860    0.000000
# 48861    0.083333
# 48862   -0.062500
# 48863    0.083333
# Name: access_p, Length: 48864, dtype: float64

# %%
df_eda.drop(str_cols, axis=1, inplace=True)

# %%
df_eda[df_eda['host_since'].isna()]
# Out:
# Empty DataFrame
# Columns: [host_since, host_response_time, host_response_rate, host_is_superhost, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, number_of_reviews, number_of_reviews_ltm, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, jurisdiction_names, instant_bookable, is_business_travel_ready, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, summary_p, summary_s, space_p, space_s, description_p, description_s, neighborhood_overview_p, neighborhood_overview_s, notes_p, notes_s, transit_p, transit_s, access_p, access_s, interaction_p, interaction_s, house_rules_p, house_rules_s, host_about_p, host_about_s]
# Index: []
#
# [0 rows x 86 columns]

# %%
# drop corrupted rows
df_eda.drop(df_eda[df_eda['host_since'].isna()].index, axis=0, inplace=True)

# %%
# turn host_since to datetime object
df_eda['host_since'] = df_eda['host_since'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
df_eda['host_since'][0]
# Out:
# Timestamp('2008-09-09 00:00:00')

# %%
df_eda['host_about'].fillna('', inplace=True)

# %%
df_eda['host_about_p'] = df_eda['host_about'].apply(lambda x: TextBlob(x).sentiment.polarity)
df_eda['host_about_s'] = df_eda['host_about'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
df_eda.drop('host_about', axis=1, inplace=True)

# %%
# use this line to drop cols
df_eda.drop(['is_business_travel_ready'], axis=1, inplace=True)

# %%
df_eda
# Out:
#       host_since  host_response_time  host_response_rate  host_is_superhost  \
# 0     2008-09-09  within a few hours                0.90                  0
# 1     2008-11-25        within a day                1.00                  0
# 2     2008-12-07      within an hour                0.90                  0
# 3     2009-01-29                   0                0.00                  0
# 4     2009-02-02  within a few hours                0.90                  0
# ...          ...                 ...                 ...                ...
# 48859 2019-08-05                   0                0.00                  0
# 48860 2010-11-26                   0                0.00                  0
# 48861 2017-01-26  within a few hours                0.96                  0
# 48862 2013-08-04                   0                0.00                  0
# 48863 2017-05-30  within a few hours                0.95                  0
#
#        host_listings_count  host_total_listings_count  \
# 0                      5.0                        5.0
# 1                      1.0                        1.0
# 2                      1.0                        1.0
# 3                      1.0                        1.0
# 4                      1.0                        1.0
# ...                    ...                        ...
# 48859                  0.0                        0.0
# 48860                  0.0                        0.0
# 48861                  1.0                        1.0
# 48862                  0.0                        0.0
# 48863                  1.0                        1.0
#
#                                       host_verifications  \
# 0      ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 1      ['email', 'phone', 'google', 'reviews', 'jumio...
# 2                   ['email', 'phone', 'reviews', 'kba']
# 3       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 4      ['email', 'phone', 'reviews', 'jumio', 'govern...
# ...                                                  ...
# 48859                                 ['email', 'phone']
# 48860  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 48861  ['email', 'phone', 'google', 'reviews', 'jumio...
# 48862  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 48863  ['email', 'phone', 'google', 'reviews', 'jumio...
#
#        host_has_profile_pic  host_identity_verified  \
# 0                         1                       1
# 1                         1                       1
# 2                         1                       1
# 3                         1                       1
# 4                         1                       0
# ...                     ...                     ...
# 48859                     1                       0
# 48860                     1                       1
# 48861                     1                       0
# 48862                     1                       1
# 48863                     1                       1
#
#       neighbourhood_group_cleansed  ... transit_p transit_s  access_p  \
# 0                        Manhattan  ... -0.077778  0.372222  0.350000
# 1                        Manhattan  ...  0.000000  0.000000  0.000000
# 2                         Brooklyn  ... -0.040000  0.245000  0.221875
# 3                        Manhattan  ...  0.000000  0.000000  0.000000
# 4                        Manhattan  ...  0.151190  0.430952  0.000000
# ...                            ...  ...       ...       ...       ...
# 48859                       Queens  ...  0.000000  0.000000  0.000000
# 48860                    Manhattan  ...  0.200000  0.433333  0.000000
# 48861                    Manhattan  ...  0.223485  0.443182  0.083333
# 48862                    Manhattan  ...  1.000000  1.000000 -0.062500
# 48863                    Manhattan  ... -0.077778  0.444444  0.083333
#
#        access_s  interaction_p  interaction_s house_rules_p house_rules_s  \
# 0      0.550000       0.370455       0.497727      0.000000      0.000000
# 1      0.000000       0.000000       0.000000     -0.057792      0.488312
# 2      0.525000       0.216667       0.344444      0.125000      0.191667
# 3      0.000000       0.000000       0.000000      0.193056      0.633333
# 4      0.000000       0.075000       0.325000      0.500000      0.700000
# ...         ...            ...            ...           ...           ...
# 48859  0.000000       0.375000       0.375000      0.000000      0.000000
# 48860  0.000000       0.347273       0.510000      0.000000      0.666667
# 48861  0.416667       0.275000       0.712500      0.142500      0.505556
# 48862  0.687500       0.800000       1.000000      0.133333      0.577778
# 48863  0.416667       0.275000       0.712500      0.054545      0.587626
#
#        host_about_p host_about_s
# 0          0.445202     0.664899
# 1          0.133939     0.396667
# 2          0.000000     0.000000
# 3          0.250000     0.300000
# 4          0.468182     0.677273
# ...             ...          ...
# 48859      0.000000     0.000000
# 48860      0.285795     0.687500
# 48861      0.000000     0.000000
# 48862      0.000000     0.000000
# 48863      0.556818     0.601515
#
# [48845 rows x 70 columns]

# %%
# turn 0 values in host_response_time back to '' or nan
# df_eda['host_response_time'].apply(lambda x: '' if x == 0)

# %%
# turn str to numerical
df_eda['host_response_rate'] = df_eda['host_response_rate'].apply(lambda x: int(x.replace('%', ''))/100 if type(x) != float else 0.0)

# %%
df_eda.drop('host_acceptance_rate', axis=1, inplace=True)

# %%
# turn cols with bool values to 0 n 1
def is_bool(df):
    for col in df.columns:
        if len(set(df_eda[col].values)) == 2:
            df_eda[col] = df_eda[col].apply(lambda x: 1 if x == 't' else 0)

# %%
is_bool(df_eda)

# %%
df_eda['host_has_profile_pic'][0]
# Out:
# 't'

# %%
# fill na with 0
df_eda['bathrooms'].fillna(0, inplace=True)
df_eda['bedrooms'].fillna(0, inplace=True)
df_eda['beds'].fillna(0, inplace=True)
df_eda['security_deposit'].fillna(0, inplace=True)
df_eda['cleaning_fee'].fillna(0, inplace=True)
df_eda['reviews_per_month'].fillna(0, inplace=True)

# %%
# change some other cols to bool
to_bool = ['square_feet', 'weekly_price', 'monthly_price']

for col in to_bool:
    df_eda[col].fillna(0, inplace=True)
    df_eda[col] = df_eda[col].apply(lambda x: 1 if x != 0 else 0)

# %%
rename_cols = {'square_feet': 'show_sqft', 'weekly_price': 'offer_weekly', 'monthly_price': 'offer_monthly'}

# %%
df_eda.rename(columns=rename_cols, inplace=True)

# %%
# fill all nan values in review scores with mean
# should consider adding some kind of noise or randomness
# current rationale: some customer might just dont like leaving reviews if there isn't anything in their experience with the listing to report

review_scores = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
                 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
                 'review_scores_value']

for col in review_scores:
    df_eda[col].fillna(np.mean(df_eda[df_eda[col].notna()][col].values), inplace=True)

# %%
df_eda['review_scores_rating'].describe()
# Out:
# count    37746.000000
# mean        93.930430
# std          8.631339
# min         20.000000
# 25%         92.000000
# 50%         96.000000
# 75%        100.000000
# max        100.000000
# Name: review_scores_rating, dtype: float64

# %%
# check for any nulls values left
n_nulls = defaultdict()
for col in df_eda.columns:
    n_nulls[col] = sum(pd.isnull(df_eda[col]).values)
    
n_nulls
# Out:
# defaultdict(None,
#             {'host_since': 0,
#              'host_response_rate': 0,
#              'host_is_superhost': 0,
#              'host_listings_count': 0,
#              'host_total_listings_count': 0,
#              'host_has_profile_pic': 0,
#              'host_identity_verified': 0,
#              'accommodates': 0,
#              'bathrooms': 0,
#              'bedrooms': 0,
#              'beds': 0,
#              'show_sqft': 0,
#              'offer_weekly': 0,
#              'offer_monthly': 0,
#              'security_deposit': 0,
#              'cleaning_fee': 0,
#              'guests_included': 0,
#              'extra_people': 0,
#              'minimum_nights': 0,
#              'maximum_nights': 0,
#              'minimum_minimum_nights': 0,
#              'maximum_minimum_nights': 0,
#              'minimum_maximum_nights': 0,
#              'maximum_maximum_nights': 0,
#              'minimum_nights_avg_ntm': 0,
#              'maximum_nights_avg_ntm': 0,
#              'number_of_reviews': 0,
#              'number_of_reviews_ltm': 0,
#              'review_scores_rating': 0,
#              'review_scores_accuracy': 0,
#              'review_scores_cleanliness': 0,
#              'review_scores_checkin': 0,
#              'review_scores_communication': 0,
#              'review_scores_location': 0,
#              'review_scores_value': 0,
#              'instant_bookable': 0,
#              'require_guest_profile_picture': 0,
#              'require_guest_phone_verification': 0,
#              'calculated_host_listings_count': 0,
#              'reviews_per_month': 0,
#              'summary_p': 0,
#              'summary_s': 0,
#              'space_p': 0,
#              'space_s': 0,
#              'description_p': 0,
#              'description_s': 0,
#              'neighborhood_overview_p': 0,
#              'neighborhood_overview_s': 0,
#              'notes_p': 0,
#              'notes_s': 0,
#              'transit_p': 0,
#              'transit_s': 0,
#              'access_p': 0,
#              'access_s': 0,
#              'interaction_p': 0,
#              'interaction_s': 0,
#              'house_rules_p': 0,
#              'house_rules_s': 0,
#              'host_about_p': 0,
#              'host_about_s': 0,
#              'response_time : a few days or more': 0,
#              'response_time : within a day': 0,
#              'response_time : within a few hours': 0,
#              'response_time : within an hour': 0,
#              'neighbor_group : Brooklyn': 0,
#              'neighbor_group : Manhattan': 0,
#              'neighbor_group : Queens': 0,
#              'neighbor_group : Staten Island': 0,
#              'property_type : Apartment': 0,
#              'property_type : Barn': 0,
#              'property_type : Bed and breakfast': 0,
#              'property_type : Boat': 0,
#              'property_type : Boutique hotel': 0,
#              'property_type : Bungalow': 0,
#              'property_type : Bus': 0,
#              'property_type : Cabin': 0,
#              'property_type : Camper/RV': 0,
#              'property_type : Casa particular (Cuba)': 0,
#              'property_type : Castle': 0,
#              'property_type : Cave': 0,
#              'property_type : Condominium': 0,
#              'property_type : Cottage': 0,
#              'property_type : Dome house': 0,
#              'property_type : Earth house': 0,
#              'property_type : Farm stay': 0,
#              'property_type : Guest suite': 0,
#              'property_type : Guesthouse': 0,
#              'property_type : Hostel': 0,
#              'property_type : Hotel': 0,
#              'property_type : House': 0,
#              'property_type : Houseboat': 0,
#              'property_type : Lighthouse': 0,
#              'property_type : Loft': 0,
#              'property_type : Nature lodge': 0,
#              'property_type : Other': 0,
#              'property_type : Resort': 0,
#              'property_type : Serviced apartment': 0,
#              'property_type : Tent': 0,
#              'property_type : Timeshare': 0,
#              'property_type : Tiny house': 0,
#              'property_type : Townhouse': 0,
#              'property_type : Treehouse': 0,
#              'property_type : Villa': 0,
#              'property_type : Yurt': 0,
#              'room_type : Private room': 0,
#              'room_type : Shared room': 0,
#              'bed_type : Couch': 0,
#              'bed_type : Futon': 0,
#              'bed_type : Pull-out Sofa': 0,
#              'bed_type : Real Bed': 0,
#              'cancellation : moderate': 0,
#              'cancellation : strict': 0,
#              'cancellation : strict_14_with_grace_period': 0,
#              'cancellation : super_strict_30': 0,
#              'cancellation : super_strict_60': 0,
#              'verification_google': 0,
#              'verification_offline_government_id': 0,
#              'verification_sent_id': 0,
#              'verification_facebook': 0,
#              'verification_manual_online': 0,
#              'verification_selfie': 0,
#              'verification_email': 0,
#              'verification_reviews': 0,
#              'verification_government_id': 0,
#              'verification_manual_offline': 0,
#              'verification_phone': 0,
#              'verification_jumio': 0,
#              'verification_sesame': 0,
#              'verification_weibo': 0,
#              'verification_work_email': 0,
#              'verification_identity_manual': 0,
#              'verification_sesame_offline': 0,
#              'verification_zhima_selfie': 0,
#              'verification_kba': 0,
#              'amenities_': 0,
#              'amenities_Crib': 0,
#              'amenities_Paid parking on premises': 0,
#              'amenities_Wide entrance': 0,
#              'amenities_Cat(s)': 0,
#              'amenities_Long term stays allowed': 0,
#              'amenities_Children’s dinnerware': 0,
#              'amenities_Single level home': 0,
#              'amenities_Fireplace guards': 0,
#              'amenities_Heating': 0,
#              'amenities_Air purifier': 0,
#              'amenities_Patio or balcony': 0,
#              'amenities_Self check-in': 0,
#              'amenities_Bed linens': 0,
#              'amenities_Internet': 0,
#              'amenities_Waterfront': 0,
#              'amenities_Lockbox': 0,
#              'amenities_Wide clearance to shower': 0,
#              'amenities_Kitchen': 0,
#              'amenities_Essentials': 0,
#              'amenities_Changing table': 0,
#              'amenities_Pool with pool hoist': 0,
#              'amenities_Cable TV': 0,
#              'amenities_Baby monitor': 0,
#              'amenities_Children’s books and toys': 0,
#              'amenities_Family/kid friendly': 0,
#              'amenities_Pack ’n Play/travel crib': 0,
#              'amenities_Beachfront': 0,
#              'amenities_Kitchenette': 0,
#              'amenities_Room-darkening shades': 0,
#              'amenities_Oven': 0,
#              'amenities_Wide hallways': 0,
#              'amenities_Outlet covers': 0,
#              'amenities_Free parking on premises': 0,
#              'amenities_Private entrance': 0,
#              'amenities_Suitable for events': 0,
#              'amenities_Dishes and silverware': 0,
#              'amenities_Lock on bedroom door': 0,
#              'amenities_Breakfast': 0,
#              'amenities_Flat path to guest entrance': 0,
#              'amenities_High chair': 0,
#              'amenities_Roll-in shower': 0,
#              'amenities_Ceiling hoist': 0,
#              'amenities_Window guards': 0,
#              'amenities_Washer / Dryer': 0,
#              'amenities_Accessible-height bed': 0,
#              'amenities_Free street parking': 0,
#              'amenities_Iron': 0,
#              'amenities_Pets live on this property': 0,
#              'amenities_Ski-in/Ski-out': 0,
#              'amenities_Full kitchen': 0,
#              'amenities_Extra space around bed': 0,
#              'amenities_Handheld shower head': 0,
#              'amenities_Smoking allowed': 0,
#              'amenities_Shower chair': 0,
#              'amenities_ toilet': 0,
#              'amenities_Luggage dropoff allowed': 0,
#              'amenities_No stairs or steps to enter': 0,
#              'amenities_Host greets you': 0,
#              'amenities_Pocket wifi': 0,
#              'amenities_Hangers': 0,
#              'amenities_Gym': 0,
#              'amenities_Babysitter recommendations': 0,
#              'amenities_Dishwasher': 0,
#              'amenities_Game console': 0,
#              'amenities_Extra pillows and blankets': 0,
#              'amenities_Beach essentials': 0,
#              'amenities_Washer': 0,
#              'amenities_Private bathroom': 0,
#              'amenities_Buzzer/wireless intercom': 0,
#              'amenities_Building staff': 0,
#              'amenities_Hot water kettle': 0,
#              'amenities_Paid parking off premises': 0,
#              'amenities_Elevator': 0,
#              'amenities_Laptop friendly workspace': 0,
#              'amenities_Microwave': 0,
#              'amenities_Well-lit path to entrance': 0,
#              'amenities_Wide entryway': 0,
#              'amenities_BBQ grill': 0,
#              'amenities_Pool': 0,
#              'amenities_Wheelchair accessible': 0,
#              'amenities_Bathtub': 0,
#              'amenities_EV charger': 0,
#              'amenities_Cleaning before checkout': 0,
#              'amenities_TV': 0,
#              'amenities_Safety card': 0,
#              'amenities_Lake access': 0,
#              'amenities_Hot water': 0,
#              'amenities_Private living room': 0,
#              'amenities_Doorman': 0,
#              'amenities_Cooking basics': 0,
#              'amenities_Stove': 0,
#              'amenities_Disabled parking spot': 0,
#              'amenities_Fixed grab bars for toilet': 0,
#              'amenities_Shampoo': 0,
#              'amenities_Table corner guards': 0,
#              'amenities_Firm mattress': 0,
#              'amenities_Accessible-height toilet': 0,
#              'amenities_Mobile hoist': 0,
#              'amenities_Fixed grab bars for shower': 0,
#              'amenities_Smart lock': 0,
#              'amenities_Other pet(s)': 0,
#              'amenities_Ethernet connection': 0,
#              'amenities_Fire extinguisher': 0,
#              'amenities_Hair dryer': 0,
#              'amenities_Keypad': 0,
#              'amenities_Air conditioning': 0,
#              'amenities_First aid kit': 0,
#              'amenities_Smoke detector': 0,
#              'amenities_Baby bath': 0,
#              'amenities_Coffee maker': 0,
#              'amenities_Wifi': 0,
#              'amenities_Refrigerator': 0,
#              'amenities_Bathtub with bath chair': 0,
#              'amenities_Pets allowed': 0,
#              'amenities_Indoor fireplace': 0,
#              'amenities_Garden or backyard': 0,
#              'amenities_Ground floor access': 0,
#              'amenities_Hot tub': 0,
#              'amenities_Stair gates': 0,
#              'amenities_Electric profiling bed': 0,
#              'amenities_Other': 0,
#              'amenities_Carbon monoxide detector': 0,
#              'amenities_24-hour check-in': 0,
#              'amenities_Wide entrance for guests': 0,
#              'amenities_Dryer': 0,
#              'amenities_Dog(s)': 0,
#              'amenities_Wide doorway to guest bathroom': 0})

# %%
# get all cols with dtype Object
obj_cols = df_eda.dtypes.values == 'O'

df_eda.columns[obj_cols]
# Out:
# Index(['host_verifications', 'amenities'], dtype='object')

# %%
get_dummies = ['host_response_time', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'bed_type', 'cancellation_policy']
dummy_prefix = ['response_time', 'neighbor_group', 'property_type', 'room_type', 'bed_type', 'cancellation']

df_eda[get_dummies]
# Out:
#        host_response_time neighbourhood_group_cleansed property_type  \
# 0      within a few hours                    Manhattan     Apartment
# 1            within a day                    Manhattan     Apartment
# 2          within an hour                     Brooklyn   Guest suite
# 3                     N/A                    Manhattan     Apartment
# 4      within a few hours                    Manhattan     Apartment
# ...                   ...                          ...           ...
# 48859                 N/A                       Queens     Apartment
# 48860                 N/A                    Manhattan     Apartment
# 48861  within a few hours                    Manhattan     Apartment
# 48862                 N/A                    Manhattan     Apartment
# 48863  within a few hours                    Manhattan     Apartment
#
#              room_type       bed_type          cancellation_policy
# 0      Entire home/apt       Real Bed  strict_14_with_grace_period
# 1         Private room  Pull-out Sofa  strict_14_with_grace_period
# 2      Entire home/apt       Real Bed                     moderate
# 3      Entire home/apt       Real Bed  strict_14_with_grace_period
# 4      Entire home/apt       Real Bed  strict_14_with_grace_period
# ...                ...            ...                          ...
# 48859      Shared room       Real Bed                     flexible
# 48860     Private room       Real Bed                     flexible
# 48861  Entire home/apt       Real Bed  strict_14_with_grace_period
# 48862     Private room       Real Bed  strict_14_with_grace_period
# 48863  Entire home/apt       Real Bed  strict_14_with_grace_period
#
# [48845 rows x 6 columns]

# %%
for col in get_dummies:
    types = set(df_eda[col].values)
    print(len(types), '    ', types, '\n')
# Out:
# 5      {'a few days or more', 'N/A', 'within an hour', 'within a few hours', 'within a day'}
#
# 5      {'Staten Island', 'Bronx', 'Brooklyn', 'Manhattan', 'Queens'}
#
# 37      {'Nature lodge', 'Guesthouse', 'Apartment', 'House', 'Casa particular (Cuba)', 'Aparthotel', 'Bungalow', 'Boat', 'Resort', 'Boutique hotel', 'Houseboat', 'Hotel', 'Dome house', 'Earth house', 'Bus', 'Cottage', 'Tent', 'Condominium', 'Townhouse', 'Lighthouse', 'Barn', 'Timeshare', 'Loft', 'Tiny house', 'Castle', 'Serviced apartment', 'Cabin', 'Treehouse', 'Other', 'Cave', 'Farm stay', 'Yurt', 'Villa', 'Hostel', 'Guest suite', 'Bed and breakfast', 'Camper/RV'}
#
# 3      {'Private room', 'Shared room', 'Entire home/apt'}
#
# 5      {'Futon', 'Real Bed', 'Airbed', 'Couch', 'Pull-out Sofa'}
#
# 6      {'strict_14_with_grace_period', 'super_strict_30', 'moderate', 'strict', 'flexible', 'super_strict_60'}

# %%
# get dummies
for i, col in enumerate(get_dummies):
    df_eda = pd.concat([df_eda, pd.get_dummies(df_eda[col], drop_first=True, prefix=dummy_prefix[i], prefix_sep=' : ')], axis=1)

# %%
df_eda.drop(df_eda[col_list[69:124]], axis=1, inplace=True)

# %%
df_eda.drop(get_dummies, axis=1, inplace=True)

# %%
df_eda['host_response_time'].replace(0, 'N/A', inplace=True)

# %%
# convert string to int for currency
to_num = ['price', 'security_deposit', 'cleaning_fee', 'extra_people']

for col in to_num:
    df_eda[col] = df_eda[col].apply(lambda x: str_to_float(x))

# %%
col_list = list(df_eda.columns)

# %%
money_test = '$2,250.00'

def str_to_float(x):
    if type(x) == int or type(x) == float:
        return float(x)
    x = x.replace('$', '')
    x = x.replace(',', '')
    return float(x)
str_to_float(money_test)
# Out:
# 2250.0

# %%
# now we deal with these two
unpack = ['host_verifications', 'amenities']

# %%
df_eda[unpack]
# Out:
#                                       host_verifications  \
# 0               {phone, work_email, email, reviews, kba}
# 1      {google, jumio, email, government_id, reviews,...
# 2                           {reviews, kba, email, phone}
# 3                 {phone, facebook, email, reviews, kba}
# 4          {jumio, email, government_id, reviews, phone}
# ...                                                  ...
# 48859                                     {email, phone}
# 48860      {jumio, email, government_id, reviews, phone}
# 48861  {google, offline_government_id, jumio, email, ...
# 48862  {jumio, work_email, email, government_id, revi...
# 48863  {google, offline_government_id, jumio, email, ...
#
#                                                amenities
# 0      {Ethernet connection, Fire extinguisher, Hair ...
# 1      {Buzzer/wireless intercom, Kitchen, Smoke dete...
# 2      {Fire extinguisher, Hair dryer, Lock on bedroo...
# 3      {Buzzer/wireless intercom, Kitchen, Smoke dete...
# 4      {Buzzer/wireless intercom, Fire extinguisher, ...
# ...                                                  ...
# 48859  {Kitchen, Smoke detector, Essentials, Pets all...
# 48860  {Kitchen, Smoke detector, Essentials, Private ...
# 48861  {Crib, Ethernet connection, Fire extinguisher,...
# 48862  {Kitchen, Smoke detector, Essentials, Laptop f...
# 48863  {Crib, Paid parking on premises, Wide entrance...
#
# [48845 rows x 2 columns]

# %%
import ast

# %%
txt_to_lst_test = df_eda['host_verifications'][0]

ast.literal_eval(txt_to_lst_test)
# Out:
# ['email', 'phone', 'reviews', 'kba', 'work_email']

# %%
txt_to_json_test = df_eda['amenities'][10]

# %%
def extract_lst(text):
    return text.replace('"', "").replace('{', "").replace('}', "").split(sep=',')

extract_lst(txt_to_json_test)
# Out:
# ['Internet',
#  'Wifi',
#  'Air conditioning',
#  'Kitchen',
#  'Doorman',
#  'Elevator',
#  'Buzzer/wireless intercom',
#  'Heating',
#  'Smoke detector',
#  'Carbon monoxide detector',
#  'Fire extinguisher',
#  'Essentials',
#  'Shampoo',
#  '24-hour check-in',
#  'Hair dryer',
#  'Iron',
#  'Laptop friendly workspace',
#  'Self check-in',
#  'Lockbox',
#  'Hot water',
#  'Long term stays allowed']

# %%
# convert host verifications from str to list
df_eda['host_verifications'] = df_eda['host_verifications'].apply(set)

# %%
# convert amenities to list
df_eda['amenities'] = df_eda['amenities'].apply(set)

# %%
empty_set = {''}

# %%
df_eda['amenities'] = df_eda['amenities'].apply(lambda x: empty_set if x == None else x)

# %%
# use to get all unique items
unique_verifications = set()
for item in df_eda['host_verifications'].values:
    unique_verifications = unique_verifications | item

unique_amenities = set()
for item in df_eda['amenities'].values:
    unique_amenities = unique_amenities | item

# %%
print(unique_verifications, '\n')
print(unique_amenities)
# Out:
# {'google', 'offline_government_id', 'sent_id', 'facebook', 'manual_online', 'selfie', 'email', 'reviews', 'government_id', 'manual_offline', 'phone', 'jumio', 'sesame', 'weibo', 'work_email', 'identity_manual', 'sesame_offline', 'zhima_selfie', 'kba'}
#
# {'', 'Crib', 'Paid parking on premises', 'Wide entrance', 'Cat(s)', 'Long term stays allowed', 'Children’s dinnerware', 'Single level home', 'Fireplace guards', 'Heating', 'Air purifier', 'Patio or balcony', 'Self check-in', 'Bed linens', 'Internet', 'Waterfront', 'Lockbox', 'Wide clearance to shower', 'Kitchen', 'Essentials', 'Changing table', 'Pool with pool hoist', 'Cable TV', 'Baby monitor', 'Children’s books and toys', 'Family/kid friendly', 'Pack ’n Play/travel crib', 'Beachfront', 'Kitchenette', 'Room-darkening shades', 'Oven', 'Wide hallways', 'Outlet covers', 'Free parking on premises', 'Private entrance', 'Suitable for events', 'Dishes and silverware', 'Lock on bedroom door', 'Breakfast', 'Flat path to guest entrance', 'High chair', 'Roll-in shower', 'Ceiling hoist', 'Window guards', 'Washer / Dryer', 'Accessible-height bed', 'Free street parking', 'Iron', 'Pets live on this property', 'Ski-in/Ski-out', 'Full kitchen', 'Extra space around bed', 'Handheld shower head', 'Smoking allowed', 'Shower chair', ' toilet', 'Luggage dropoff allowed', 'No stairs or steps to enter', 'Host greets you', 'Pocket wifi', 'Hangers', 'Gym', 'Babysitter recommendations', 'Dishwasher', 'Game console', 'Extra pillows and blankets', 'Beach essentials', 'Washer', 'Private bathroom', 'Buzzer/wireless intercom', 'Building staff', 'Hot water kettle', 'Paid parking off premises', 'Elevator', 'Laptop friendly workspace', 'Microwave', 'Well-lit path to entrance', 'Wide entryway', 'BBQ grill', 'Pool', 'Wheelchair accessible', 'Bathtub', 'EV charger', 'Cleaning before checkout', 'TV', 'Safety card', 'Lake access', 'Hot water', 'Private living room', 'Doorman', 'Cooking basics', 'Stove', 'Disabled parking spot', 'Fixed grab bars for toilet', 'Shampoo', 'Table corner guards', 'Firm mattress', 'Accessible-height toilet', 'Mobile hoist', 'Fixed grab bars for shower', 'Smart lock', 'Other pet(s)', 'Ethernet connection', 'Fire extinguisher', 'Hair dryer', 'Keypad', 'Air conditioning', 'First aid kit', 'Smoke detector', 'Baby bath', 'Coffee maker', 'Wifi', 'Refrigerator', 'Bathtub with bath chair', 'Pets allowed', 'Indoor fireplace', 'Garden or backyard', 'Ground floor access', 'Hot tub', 'Stair gates', 'Electric profiling bed', 'Other', 'Carbon monoxide detector', '24-hour check-in', 'Wide entrance for guests', 'Dryer', 'Dog(s)', 'Wide doorway to guest bathroom'}

# %%
# create dummies of host verifications
for i in unique_verifications:
    col_name = 'verification_' + i
    df_eda[col_name] = df_eda['host_verifications'].apply(lambda x: 1 if i in x else 0)

# %%
# create dummies of amenities
for i in unique_amenities:
    col_name = 'amenities_' + i
    df_eda[col_name] = df_eda['amenities'].apply(lambda x : 1 if i in x else 0)

# %%
# df_eda.drop(unique_verifications, axis=1, inplace=True)

# %%
# use this to fix accidental Nones
# df_eda['amenities'] = df_eda['amenities'].apply(lambda x: empty_set if x == None else x)

# %%
check_this = df_eda.iloc[946,5]

# %%
check_this
# Out:
# {'email', 'government_id', 'jumio', 'kba', 'phone', 'reviews'}

# %%
df_eda.drop(df_eda[df_eda['cancellation_policy'].isna()].index, axis=0, inplace=True)

# %%
df_orig[df_orig['cancellation_policy'].isna()]['host_url']
# Out:
# 48818    https://www.airbnb.com/users/show/278187111
# Name: host_url, dtype: object

# %%
df_eda['host_since'] = df_eda['host_since'].apply(lambda x: 2020 - x.year)

# %%
df_eda.to_csv('data/2019aug/cleaned_dlistings.csv', index=False)

# %%
y = df_eda.pop('price')

# %%
y.to_csv('data/2019aug/prices.csv')

# %%
X = df_eda

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
X1 = sm.add_constant(X)

# %%
olsmodel = sm.OLS(y, X1.astype(float))

olsmodel = olsmodel.fit()

# %%
olsmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     50.77
# Date:                Wed, 26 Aug 2020   Prob (F-statistic):               0.00
# Time:                        09:13:36   Log-Likelihood:            -3.3045e+05
# No. Observations:               48845   AIC:                         6.614e+05
# Df Residuals:                   48584   BIC:                         6.637e+05
# Df Model:                         260
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                        -70.0617     63.855     -1.097      0.273    -195.218      55.095
# host_since                                     1.4502      0.624      2.326      0.020       0.228       2.672
# host_response_rate                           -38.2092     12.965     -2.947      0.003     -63.620     -12.799
# host_is_superhost                             11.5820      2.890      4.007      0.000       5.917      17.247
# host_listings_count                            0.0276      0.010      2.861      0.004       0.009       0.046
# host_total_listings_count                      0.0276      0.010      2.859      0.004       0.009       0.046
# host_has_profile_pic                          22.1533     21.386      1.036      0.300     -19.763      64.069
# host_identity_verified                         4.9262      2.951      1.669      0.095      -0.857      10.710
# accommodates                                  28.0105      0.964     29.058      0.000      26.121      29.900
# bathrooms                                     61.2552      2.580     23.747      0.000      56.199      66.311
# bedrooms                                      22.9517      1.944     11.806      0.000      19.141      26.762
# beds                                          -6.5784      1.434     -4.588      0.000      -9.389      -3.768
# show_sqft                                    -17.8601     11.409     -1.565      0.117     -40.222       4.502
# offer_weekly                                  -0.0220      4.235     -0.005      0.996      -8.323       8.279
# offer_monthly                                -19.6005      4.471     -4.384      0.000     -28.363     -10.838
# security_deposit                               0.0280      0.003     11.064      0.000       0.023       0.033
# cleaning_fee                                   0.2550      0.023     10.887      0.000       0.209       0.301
# guests_included                               -8.8897      1.108     -8.026      0.000     -11.061      -6.719
# extra_people                                   0.2217      0.043      5.162      0.000       0.138       0.306
# minimum_nights                                -0.1563      0.276     -0.566      0.571      -0.697       0.385
# maximum_nights                                 0.0437      0.020      2.214      0.027       0.005       0.082
# minimum_minimum_nights                         0.3746      0.281      1.334      0.182      -0.176       0.925
# maximum_minimum_nights                         0.0069      0.060      0.116      0.908      -0.111       0.125
# minimum_maximum_nights                        -0.0075      0.048     -0.156      0.876      -0.102       0.087
# amenities_24-hour check-in                     1.8883      3.773      0.500      0.617      -5.507       9.284
# amenities_Wide entrance for guests            -0.9385      7.645     -0.123      0.902     -15.923      14.047
# amenities_Dryer                                7.8391      7.258      1.080      0.280      -6.388      22.066
# amenities_Dog(s)                              -3.4230      8.271     -0.414      0.679     -19.633      12.787
# amenities_Wide doorway to guest bathroom      -0.6540     10.683     -0.061      0.951     -21.592      20.284
# ==============================================================================
# Omnibus:                   116045.953   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1561917044.991
# Skew:                          24.193   Prob(JB):                         0.00
# Kurtosis:                     877.704   Cond. No.                     5.70e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.67e-17. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, 
from sklearn import tree

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)

mse_reg = mean_squared_error(y_test,reg.predict(X_test))
mse_reg
# lol
# Out:
# 35982.205288017365

# %%
r2_reg = r2_score(y_test, reg.predict(X_test))
r2_reg
# Out:
# 0.24445967702555438

# %%
params = {'n_estimators': 1000, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}

gbt = GradientBoostingRegressor(**params)
gbt.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=4, n_estimators=1000)

# %%
gbt.feature_importances_
# Out:
# array([6.01349550e-03, 2.76721758e-03, 8.66749982e-05, 9.22484777e-04,
#        5.64651115e-04, 4.51113533e-06, 4.45269235e-05, 1.18043071e-01,
#        6.70406630e-02, 4.41174900e-02, 1.41721486e-02, 4.58860981e-07,
#        6.00038313e-06, 6.31449946e-05, 1.44708054e-02, 6.73177544e-02,
#        5.90803072e-04, 1.43739628e-02, 3.42737447e-02, 6.81155163e-03,
#        5.74203461e-02, 1.42970322e-02, 7.72487783e-03, 7.07444621e-03,
#        9.98960162e-03, 5.24428070e-03, 2.98141970e-03, 3.00728837e-04,
#        3.29188875e-02, 1.81793292e-04, 3.53115872e-03, 5.67200266e-03,
#        1.43620289e-05, 3.08042776e-03, 8.37664485e-04, 6.68314877e-04,
#        1.60018512e-03, 1.44282420e-03, 2.46025244e-03, 1.48438688e-02,
#        1.54452738e-02, 9.65611247e-03, 1.00070036e-02, 1.14422803e-02,
#        4.81469863e-02, 5.20387732e-03, 8.64824363e-03, 8.50419722e-04,
#        1.33047233e-04, 4.79559689e-05, 6.99650656e-04, 1.97807923e-03,
#        3.58585066e-02, 7.19185460e-04, 3.06851997e-03, 5.95189052e-04,
#        2.81863707e-03, 3.82362375e-04, 2.16710845e-03, 7.00255843e-03,
#        2.36527732e-03, 9.95214686e-05, 1.42097229e-04, 7.24808888e-03,
#        1.62838390e-03, 3.85967194e-02, 3.38881148e-03, 8.29525462e-05,
#        2.87695527e-03, 0.00000000e+00, 0.00000000e+00, 3.62378787e-02,
#        2.07651693e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.26947562e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.77863786e-04, 4.58819322e-04, 0.00000000e+00, 0.00000000e+00,
#        4.35635251e-03, 0.00000000e+00, 1.06783367e-02, 2.65584712e-03,
#        1.33535675e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.46926525e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.91438199e-02, 3.31981496e-03, 7.37223615e-04, 0.00000000e+00,
#        0.00000000e+00, 2.37069762e-05, 2.28851385e-04, 0.00000000e+00,
#        2.84811204e-05, 0.00000000e+00, 0.00000000e+00, 2.03249683e-07,
#        5.20989791e-04, 4.24510288e-05, 2.75043579e-04, 0.00000000e+00,
#        1.57778212e-05, 1.28872335e-02, 3.66545888e-04, 1.25947540e-03,
#        2.54627146e-05, 0.00000000e+00, 1.56012788e-03, 0.00000000e+00,
#        0.00000000e+00, 8.41417075e-04, 9.27976817e-04, 0.00000000e+00,
#        0.00000000e+00, 1.03718937e-04, 1.37752415e-03, 5.69649986e-04,
#        3.11072646e-04, 0.00000000e+00, 0.00000000e+00, 5.59045124e-07,
#        6.02605478e-04, 2.94097814e-04, 5.27939838e-06, 2.22335209e-03,
#        0.00000000e+00, 6.30882817e-06, 2.88418136e-05, 5.46980024e-08,
#        2.10860943e-04, 2.95179656e-06, 5.01732713e-07, 2.94791377e-06,
#        1.31908953e-02, 1.16168644e-02, 3.01693700e-05, 0.00000000e+00,
#        4.84076496e-03, 7.12860794e-08, 1.57920189e-06, 3.42595451e-04,
#        2.11521211e-05, 8.74115543e-06, 0.00000000e+00, 8.24021771e-04,
#        1.15789188e-04, 2.86818461e-04, 0.00000000e+00, 2.73794055e-04,
#        4.13453176e-04, 1.82331042e-03, 3.72959259e-04, 2.53666219e-04,
#        1.03069174e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.21420853e-04, 0.00000000e+00, 0.00000000e+00,
#        1.05936065e-03, 3.03118814e-05, 3.11543582e-05, 0.00000000e+00,
#        0.00000000e+00, 1.84056969e-03, 1.76009488e-05, 1.82887990e-04,
#        0.00000000e+00, 0.00000000e+00, 3.31339778e-05, 8.66162616e-09,
#        5.08023525e-06, 0.00000000e+00, 4.90166518e-04, 7.08120609e-03,
#        3.67944654e-06, 9.81756472e-05, 4.05194741e-03, 9.90757468e-07,
#        0.00000000e+00, 1.41695571e-03, 0.00000000e+00, 1.69422795e-03,
#        1.88892550e-03, 8.36742499e-06, 1.22706082e-04, 7.36224085e-03,
#        3.30928960e-04, 3.58306722e-04, 1.58101665e-03, 0.00000000e+00,
#        5.04750762e-04, 7.97035469e-03, 6.14358632e-03, 5.04775641e-05,
#        0.00000000e+00, 0.00000000e+00, 3.13135382e-04, 3.02277849e-06,
#        0.00000000e+00, 7.76886772e-05, 1.20706838e-07, 1.63819181e-03,
#        3.23820458e-04, 1.04508044e-07, 0.00000000e+00, 2.52287575e-05,
#        5.05570879e-04, 1.45153187e-05, 0.00000000e+00, 1.75299772e-04,
#        0.00000000e+00, 0.00000000e+00, 5.17071466e-07, 1.15719159e-05,
#        1.87995636e-03, 2.01048451e-04, 2.58368157e-04, 2.93017995e-04,
#        6.00122564e-03, 2.06585935e-04, 6.88619767e-04, 1.32185428e-05,
#        2.39118170e-05, 6.91644478e-04, 3.64679411e-05, 0.00000000e+00,
#        3.34793039e-04, 1.30383580e-03, 1.18244319e-05, 0.00000000e+00,
#        1.27331501e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.64532397e-04, 1.03434922e-05, 0.00000000e+00, 1.65303017e-03,
#        0.00000000e+00, 0.00000000e+00])

# %%
mse_gbt = mean_squared_error(y_test, gbt.predict(X_test))
mse_gbt
# Out:
# 33379.71408592212

# %%
r2_gbt = r2_score(y_train, gbt.predict(X_train))
r2_gbt
# Out:
# 0.6171124905662771
